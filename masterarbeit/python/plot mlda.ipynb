# %%
import h5py
import numpy as np
import arviz as az
import matplotlib.pyplot as plt

# %%
fin = h5py.File('/home/anne/Masterarbeit/masterarbeit/results/samples5_mlda.h5')
samples_mlda = np.array( fin['/samples'] )
fin.close()

# %%
az.plot_trace(samples_mlda[0,:])
az.plot_trace(samples_mlda[1,:])
az.plot_trace(samples_mlda[2,:])
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'x'}>]], dtype=object)

# %%
fig = plt.figure(figsize = (10, 7))
ax = plt.axes()

ax.plot(samples_mlda[0,:])

# %%
print("Means")
print(np.mean(samples_mlda, axis=1))

print("\nVariance")
print(np.var(samples_mlda, axis=1))
# Out:
# Means
# [116.90146357 128.38486543 125.50164989]
#
# Variance
# [0.69939782 0.81238044 0.72324496]

# %%
print(samples_mlda[:,98900:99000])
# Out:
# []
