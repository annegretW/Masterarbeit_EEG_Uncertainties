# %%
import h5py
import numpy as np
import arviz as az
import matplotlib.pyplot as plt

# %%
fin = h5py.File('/home/anne/Masterarbeit/masterarbeit/results/samples_10_l0.h5')
samples_l0 = np.array( fin['/samples'] )

fin = h5py.File('/home/anne/Masterarbeit/masterarbeit/results/samples_10_l1.h5')
samples_l1 = np.array( fin['/samples'] )

fin = h5py.File('/home/anne/Masterarbeit/masterarbeit/results/samples_10_l2.h5')
samples_l2 = np.array( fin['/samples'] )

fin = h5py.File('/home/anne/Masterarbeit/masterarbeit/results/samples_10_mlda.h5')
samples_mlda = np.array( fin['/samples'] )

# %%
sampMean = samples_l0.Mean()
print(f"Sample Mean = {sampMean.transpose()}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/anne/Masterarbeit/muq2/examples/SamplingAlgorithms/MCMC/MLDA/cpp/plot.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/anne/Masterarbeit/muq2/examples/SamplingAlgorithms/MCMC/MLDA/cpp/plot.ipynb#ch0000006vscode-remote?line=0'>1</a> sampMean = samples_l0.Mean()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/anne/Masterarbeit/muq2/examples/SamplingAlgorithms/MCMC/MLDA/cpp/plot.ipynb#ch0000006vscode-remote?line=1'>2</a> print(f"Sample Mean = {sampMean.transpose()}")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'Mean'

# %%
plt.scatter(samples_l0[0,:], samples_l0[1,:], alpha=.01, color='b')
plt.scatter(samples_l1[0,:], samples_l1[1,:], alpha=.01, color='r')
plt.scatter(samples_l2[0,:], samples_l2[1,:], alpha=.01, color='g')
#plt.scatter(samples_mlda[0,:], samples_mlda[1,:], alpha=.01, color='g')

plt.xlabel('Samples X')
plt.ylabel('Samples Y')
plt.savefig("samples.png")
plt.show()

plt.scatter(samples_l2[0,:], samples_l2[1,:], alpha=.01, color='b')
plt.scatter(samples_mlda[0,:], samples_mlda[1,:], alpha=.1, color='r')
plt.xlabel('Samples X')
plt.ylabel('Samples Y')
plt.savefig("samples_mlda.png")
plt.show()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20,5))
fig.subplots_adjust(wspace=.5)

az.plot_dist(samples_l0[0,:],samples_l0[1,:],
            textsize=18, ax=ax1)#,
ax1.set_xlabel('Samples X')
ax1.set_ylabel('Samples Y')

az.plot_dist(samples_l1[0,:],samples_l1[1,:],
            textsize=18, ax=ax2)#,
ax2.set_xlabel('Samples X')
ax2.set_ylabel('Samples Y')

az.plot_dist(samples_l2[0,:],samples_l2[1,:],
            textsize=18, ax=ax3)#,
ax3.set_xlabel('Samples X')
ax3.set_ylabel('Samples Y')

az.plot_dist(samples_mlda[0,:],samples_mlda[1,:],
            textsize=18, ax=ax4)#,
ax4.set_xlabel('Samples X')
ax4.set_ylabel('Samples Y')

plt.savefig("contour.png")

# %%
az.plot_trace(samples_l2[0,:])
az.plot_trace(samples_mlda[0,:])
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'x'}>]], dtype=object)
